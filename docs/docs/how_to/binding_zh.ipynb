# %% [raw]
# ---
# sidebar_position: 2
# keywords: [RunnableBinding, LCEL]
# ---

# %% [markdown]
# # 如何为Runnable添加默认调用参数
# :::info 前提条件
# 本指南假定您已熟悉以下概念：- [LangChain 表达式语言 (LCEL)](/docs/concepts/lcel)- [链式运行](/docs/how_to/sequence/)- [工具调用](/docs/how_to/tool_calling)
# :::
# 有时我们希望在 [RunnableSequence](https://python.langchain.com/api_reference/core/runnables/langchain_core.runnables.base.RunnableSequence.html) 中调用一个 [`Runnable`](https://python.langchain.com/api_reference/core/runnables/langchain_core.runnables.base.Runnable.html)，并传入一些常量参数——这些参数既不是序列中前一个 Runnable 的输出，也不属于用户输入。这时可以使用 [`Runnable.bind()`](https://python.langchain.com/api_reference/langchain_core/runnables/langchain_core.runnables.base.Runnable.html#langchain_core.runnables.base.Runnable.bind) 方法预先绑定这些参数。
# ## 绑定停止序列
# 假设我们有一个简单的提示词+模型链：

# %%
# | output: false
# | echo: false

# %pip install -qU langchain langchain_openai

import os
from getpass import getpass

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass()

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "Write out the following equation using algebraic symbols then solve it. Use the format\n\nEQUATION:...\nSOLUTION:...\n\n",
        ),
        ("human", "{equation_statement}"),
    ]
)

model = ChatOpenAI(temperature=0)

runnable = (
    {"equation_statement": RunnablePassthrough()} | prompt | model | StrOutputParser()
)

print(runnable.invoke("x raised to the third plus seven equals 12"))
# Out:
# EQUATION: x^3 + 7 = 12
#
# SOLUTION:
# Subtract 7 from both sides:
# x^3 = 5
#
# Take the cube root of both sides:
# x = ∛5

# %% [markdown]
# 并希望通过设置特定的`stop`词来调用模型，以便在某些类型的提示技术中有效缩短输出内容。虽然我们可以通过构造函数传递部分参数，但其他运行时参数需使用`.bind()`方法实现，具体如下：

# %%
runnable = (
    {"equation_statement": RunnablePassthrough()}
    | prompt
    | model.bind(stop="SOLUTION")
    | StrOutputParser()
)

print(runnable.invoke("x raised to the third plus seven equals 12"))
# Out:
# EQUATION: x^3 + 7 = 12

# %% [markdown]
# 你可以绑定到 Runnable 的内容将取决于调用时可传递的额外参数。
# ## 附加OpenAI工具
# 另一个常见用例是工具调用。虽然通常建议使用 [`.bind_tools()`](/docs/how_to/tool_calling) 方法处理工具调用模型，但若需要更底层的控制，也可以直接绑定特定于供应商的参数：

# %%
tools = [
    {
        "type": "function",
        "function": {
            "name": "get_current_weather",
            "description": "Get the current weather in a given location",
            "parameters": {
                "type": "object",
                "properties": {
                    "location": {
                        "type": "string",
                        "description": "The city and state, e.g. San Francisco, CA",
                    },
                    "unit": {"type": "string", "enum": ["celsius", "fahrenheit"]},
                },
                "required": ["location"],
            },
        },
    }
]

# %%
model = ChatOpenAI(model="gpt-4o-mini").bind(tools=tools)
model.invoke("What's the weather in SF, NYC and LA?")
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_z0OU2CytqENVrRTI6T8DkI3u', 'function': {'arguments': '{"location": "San Francisco, CA", "unit": "celsius"}', 'name': 'get_current_weather'}, 'type': 'function'}, {'id': 'call_ft96IJBh0cMKkQWrZjNg4bsw', 'function': {'arguments': '{"location": "New York, NY", "unit": "celsius"}', 'name': 'get_current_weather'}, 'type': 'function'}, {'id': 'call_tfbtGgCLmuBuWgZLvpPwvUMH', 'function': {'arguments': '{"location": "Los Angeles, CA", "unit": "celsius"}', 'name': 'get_current_weather'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 85, 'total_tokens': 169}, 'model_name': 'gpt-4o-mini', 'system_fingerprint': 'fp_77a673219d', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d57ad5fa-b52a-4822-bc3e-74f838697e18-0', tool_calls=[{'name': 'get_current_weather', 'args': {'location': 'San Francisco, CA', 'unit': 'celsius'}, 'id': 'call_z0OU2CytqENVrRTI6T8DkI3u'}, {'name
# ...

# %% [markdown]
# ## 后续步骤
# 你现在已经知道如何将运行时参数绑定到一个可运行对象上。
# 要了解更多信息，请参阅本节中关于可运行项的其他操作指南，包括：
# - [使用可配置字段和替代方案](/docs/how_to/configure) 在运行时更改链中步骤的参数，甚至替换整个步骤
